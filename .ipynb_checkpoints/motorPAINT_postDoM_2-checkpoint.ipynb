# %% [markdown]
# ### motorPAINT processing
#
# MK Iwanski <br>
# Universiteit Utrecht, Kaptein Lab <br>
# 2020-04-07
#
# Based on the following codes from R Tan:
# * 20160905_Dom1.0 Interpolation_applied to full dataset.py
# * 20160929_ParticleSep_Ability to choose DriftCorrFile or both Raw_Python3_Dom-V1.x.py

# %%
# imports
import numpy as np
import math

import sys as sys
import os
import tkinter as tk
from tkinter import filedialog

import matplotlib.pylab as plt
import time

# %%
# function for debugging
def pause():
    programPause = input('Press <ENTER> to continue.')

# %%
root = tk.Tk()
root.withdraw()

directory = filedialog.askdirectory(title = 'choose filtered particles Table format:.csv' ) 
os.chdir(directory)

# %%
def interpolate():
    
    infile = open(directory+'/'+filename)
    myfile = open(filename+'_Interpolation1.csv','a+')
    title = infile.readline()[:-1]

    myfile.write(title + '\n')
    
    fixed = 20   #fixed distance between points

    prevline = infile.readline()
    myfile.write(prevline)

#    print(prevline)
    for line2 in infile:
        
    #    print(line)
        tid = int(prevline.split(',')[23])  #trackid
        pid = int(prevline.split(',')[24])  #particleid
        x = float(prevline.split(',')[4])
        xerror = float(prevline.split(',')[5])
        yerror = float(prevline.split(',')[7])
        y = float(prevline.split(',')[6])
        trlen = int(prevline.split(',')[25])
        xy = (x,y)

        frame = int(float(prevline.split(',')[3]))
        myfile.write(line2)
        
        tid2 = int(line2.split(',')[23])  #trackid
        pid2 = int(line2.split(',')[24])  #particleid
        x2 = float(line2.split(',')[4])
        print((line2.split(',')[5]))
        xerror2 = float(line2.split(',')[5])
        yerror2 = float(line2.split(',')[7])
        y2 = float(line2.split(',')[6])
        trlen2 = int(line2.split(',')[25])
        nr = 0
      
        if pid2 != 1:
        
            dx = (x2 - x) 
            dy = (y2 - y) 
            distance = math.sqrt(dx**2 + dy**2)
            nr = round((distance/fixed),0)
            
#        print(x,x2,dx, distance, math.sqrt(dx),x2-x, (x2-x)**2, nr)       
        
            for i in range(int(nr)):
                xpix = (x + (i+1) * (dx/nr)) /65
                ypix = (y + (i+1) * (dy/nr)) /65
                xnm =  x + (i+1) * (dx/nr) 
                ynm =  y + (i+1) * (dy/nr)
                xloc = (xerror + xerror2)/2
                yloc = (yerror + yerror2)/2
                line3 = line2.replace((line2.split(',')[1]+','+line2.split(',')[2]+','+line2.split(',')[3]+','+line2.split(',')[4]+','+line2.split(',')[5] +','+line2.split(',')[6] +','+line2.split(',')[7]), (str(xpix) + ',' + str(ypix) +','+line2.split(',')[3] + ',' + str(xnm) +','+str(xloc) + ',' + str(ynm)+ ',' + str(yloc)))
                myfile.write(line3)
#                print(i)
        
        prevline = line2
        #print(tid,pid,pid2, nr,(distance/fixed), i)

    myfile.close()

# %%
for filename in os.listdir(directory):
    
    print(filename)
    savename = filename[-6:-4]
    print (savename, '1')
    if savename in ('RT', 'LB', 'LT', 'RB'):
        print(type(savename))
        interpolate()

"""    if frame in d_nm.keys():
            xpix = float(line2.split(',')[1])+d_pix[frame][0]
            ypix = float(line2.split(',')[2])+d_pix[frame][1]
            xnm = float(line2.split(',')[4])+d_nm[frame][0]
            ynm = float(line2.split(',')[6])+d_nm[frame][1]
        elif frame < int(b) :
            xpix = float(line2.split(',')[1])+d_pix[b][0]
            ypix = float(line2.split(',')[2])+d_pix[b][1]
            xnm = float(line2.split(',')[4])+d_nm[b][0]
            ynm = float(line2.split(',')[6])+d_nm[b][1]
        else:
            xpix = float(line2.split(',')[1])+d_pix[a][0]
            ypix = float(line2.split(',')[2])+d_pix[a][1]
            xnm = float(line2.split(',')[4])+d_nm[a][0]
            ynm = float(line2.split(',')[6])+d_nm[a][1]        
            
       line3 = line2.replace((line2.split(',')[1]+','+line2.split(',')[2]+','+line2.split(',')[3]+','+line2.split(',')[4]+','+line2.split(',')[5] +','+line2.split(',')[6]), (str(xpix) + ',' + str(ypix) +','+line2.split(',')[3] + ',' + str(xnm) +','+line2.split(',')[5] + ',' + str(ynm)))
        #print(line2, '\n', line3)
    
#    line3 = line2[:-1] +','+ str(xnm) + ',' + str(ynm) + '\n'
        myfile.write(line3)

    myfile.close()

"""
